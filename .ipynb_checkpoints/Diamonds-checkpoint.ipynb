# %%
import pandas as pd 
data=pd.read_csv("diamonds.csv")
data.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
data.shape
# Out:
# (53940, 11)

# %% [markdown]
# ## preprocessing

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# ## Data Clearing

# %%
data = data.drop(["cut","color","clarity"],axis=1)

# %%
data.head()
# Out:
#    Unnamed: 0  carat  depth  table  price     x     y     z
# 0           1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1           2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2           3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3           4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4           5   0.31   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# ## Data Analysis

# %%
import matplotlib.pyplot as plt
import  seaborn as sns

# %%
sns.pairplot(data[["carat","depth","table","price"]])
plt.show()

# %% [markdown]
#  ## Cleaning Charts

# %%
sns.displot(data["price"])

# %%
q= data["price"].quantile(0.99)
q
## don't need to clear
# Out:
# 17378.22

# %%
sns.displot(data["carat"])

# %%
q= data["carat"].quantile(0.99)
q
# Out:
# 2.18

# %%
data=data[data["carat"]<q]

# %%
sns.displot(data["carat"])

# %%
sns.displot(data["depth"])

# %%
q= data["depth"].quantile(0.99)
q
# Out:
# 65.5

# %%
qq= data["depth"].quantile(0.01)
qq
# Out:
# 57.9

# %%
data=data[data["depth"]<q]

# %%
data=data[data["depth"]>qq]

# %%
sns.displot(data["depth"])

# %%
sns.displot(data["table"])
##noo need

# %% [markdown]
# ## Create The Model

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(16,3))
ax1.scatter(data["carat"],data["price"])
ax1.set_title("Carat Vs Price")
ax2.scatter(data["depth"],data["price"])
ax2.set_title("Depth Vs Price")
ax3.scatter(data["table"],data["price"])
ax3.set_title("Table Vs Price")
# Out:
# Text(0.5, 1.0, 'Table Vs Price')

# %%
import numpy as np

# %%
data["log_price"]=np.log(data["price"])

# %%
data.head()
# Out:
#    Unnamed: 0  carat  depth  table  price     x     y     z  log_price
# 0           1   0.23   61.5   55.0    326  3.95  3.98  2.43   5.786897
# 1           2   0.21   59.8   61.0    326  3.89  3.84  2.31   5.786897
# 3           4   0.29   62.4   58.0    334  4.20  4.23  2.63   5.811141
# 4           5   0.31   63.3   58.0    335  4.34  4.35  2.75   5.814131
# 5           6   0.24   62.8   57.0    336  3.94  3.96  2.48   5.817111

# %%
f,(ax1,ax2,ax3)=plt.subplots(1,3,figsize=(16,3))
ax1.scatter(data["carat"],data["log_price"])
ax1.set_title("Carat Vs Price")
ax2.scatter(data["depth"],data["log_price"])
ax2.set_title("Depth Vs Price")
ax3.scatter(data["table"],data["log_price"])
ax3.set_title("Table Vs Price")
# Out:
# Text(0.5, 1.0, 'Table Vs Price')

# %%
new_data=data.drop(["price"],axis=1)
new_data
# Out:
#        Unnamed: 0  carat  depth  table     x     y     z  log_price
# 0               1   0.23   61.5   55.0  3.95  3.98  2.43   5.786897
# 1               2   0.21   59.8   61.0  3.89  3.84  2.31   5.786897
# 3               4   0.29   62.4   58.0  4.20  4.23  2.63   5.811141
# 4               5   0.31   63.3   58.0  4.34  4.35  2.75   5.814131
# 5               6   0.24   62.8   57.0  3.94  3.96  2.48   5.817111
# ...           ...    ...    ...    ...   ...   ...   ...        ...
# 53935       53936   0.72   60.8   57.0  5.75  5.76  3.50   7.921898
# 53936       53937   0.72   63.1   55.0  5.69  5.75  3.61   7.921898
# 53937       53938   0.70   62.8   60.0  5.66  5.68  3.56   7.921898
# 53938       53939   0.86   61.0   58.0  6.15  6.12  3.74   7.921898
# 53939       53940   0.75   62.2   55.0  5.83  5.87  3.64   7.921898
#
# [52234 rows x 8 columns]

# %% [markdown]
# ## Linerity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
features = data [["carat","depth","table"]]
vif=[variance_inflation_factor(features.values,i) for i in range(features.shape[1])]
vif
# Out:
# [4.161230247543778, 447.36214247142294, 456.92779567488896]

# %%
new=data.drop(["table"],axis=1)

# %%
features = data [["carat","depth"]]
vif=[variance_inflation_factor(features.values,i) for i in range(features.shape[1])]
vif
# Out:
# [4.044302901240949, 4.044302901240949]

# %%
x= new[["carat","depth"]]
y = new["log_price"]

# %%
x
# Out:
#        carat  depth
# 0       0.23   61.5
# 1       0.21   59.8
# 3       0.29   62.4
# 4       0.31   63.3
# 5       0.24   62.8
# ...      ...    ...
# 53935   0.72   60.8
# 53936   0.72   63.1
# 53937   0.70   62.8
# 53938   0.86   61.0
# 53939   0.75   62.2
#
# [52234 rows x 2 columns]

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.compose import make_column_transformer

ct = make_column_transformer(
    (StandardScaler(),['carat','depth'])
    )

x_new= ct.fit_transform(x)

# %% [markdown]
# ## Train and Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# ## Training

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = reg.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.2839952149014133

# %%
x
# Out:
#        carat  depth
# 0       0.23   61.5
# 1       0.21   59.8
# 3       0.29   62.4
# 4       0.31   63.3
# 5       0.24   62.8
# ...      ...    ...
# 53935   0.72   60.8
# 53936   0.72   63.1
# 53937   0.70   62.8
# 53938   0.86   61.0
# 53939   0.75   62.2
#
# [52234 rows x 2 columns]

# %%
test=[0.50,61.5]

# %%
x.columns.values
# Out:
# array(['carat', 'depth'], dtype=object)

# %%
df = pd.DataFrame(columns=x.columns.values,data=[test])
df
# Out:
#    carat  depth
# 0    0.5   61.5

# %%
df_scaled=ct.transform(df)

# %%
reg.predict(df_scaled)
# Out:
# array([5.60553609])

# %%
np.exp(reg.predict(df_scaled))
# Out:
# array([271.92766345])

# %% [markdown]
# ## Deploy
